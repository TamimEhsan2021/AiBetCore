# %%
import pandas as pd
from sklearn import model_selection

df = pd.read_csv("post2015_master_set.csv")

# %%
df.shape
# Out:
# (26824, 22)

# %%
df
# Out:
#        Unnamed: 0          Home_Team         Away_Team Result  \
# 0               0            Watford     Middlesbrough    1-0
# 1               1    Birmingham City         Brentford    1-0
# 2               2  Wycombe Wanderers  Rotherham United    0-1
# 3               3    AFC Bournemouth  Blackburn Rovers    3-2
# 4               4           Barnsley        Luton Town    0-1
# ...           ...                ...               ...    ...
# 26819       26820               Pisa          Vicenza     2-2
# 26820       26821            Pescara             Lecce    1-1
# 26821       26822               SPAL           Reggina    1-4
# 26822       26823           AC Monza        Cittadella    0-0
# 26823       26824     Virtus Entella           Brescia    1-1
#
#                                                     Link  Season  Round  \
# 0      https://www.besoccer.com/match/watford-fc/midd...    2021      1
# 1      https://www.besoccer.com/match/birmingham-city...    2021      1
# 2      https://www.besoccer.com/match/wycombe-wandere...    2021      1
# 3      https://www.besoccer.com/match/afc-bournemouth...    2021      1
# 4      https://www.besoccer.com/match/barnsley-fc/lut...    2021      1
# ...                                                  ...     ...    ...
# 26819  https://www.besoccer.com/match/pisa-calcio/vic...    2021     25
# 26820  https://www.besoccer.com/match/pescara-calcio/...    2021     25
# 26821  https://www.besoccer.com/match/spal-1907/reggi...    2021     25
# 26822  https://www.besoccer.com/match/ac-monza-brianz...    2021     25
# 26823  https://www.besoccer.com/match/virtus-entella/...    2021     25
#
#              League                                     reduced_link  \
# 0      championship          /match/watford-fc/middlesbrough-fc/2021
# 1      championship         /match/birmingham-city-fc/brentford/2021
# 2      championship   /match/wycombe-wanderers/rotherham-united/2021
# 3      championship  /match/afc-bournemouth/blackburn-rovers-fc/2021
# 4      championship            /match/barnsley-fc/luton-town-fc/2021
# ...             ...                                              ...
# 26819       serie_b           /match/pisa-calcio/vicenza-calcio/2021
# 26820       serie_b                 /match/pescara-calcio/lecce/2021
# 26821       serie_b                    /match/spal-1907/reggina/2021
# 26822       serie_b  /match/ac-monza-brianza-1912/as-cittadella/2021
# 26823       serie_b               /match/virtus-entella/brescia/2021
#
#                                  Date_New  ... Home_Red  Away_Yellow  \
# 0        Friday, 11 September 2020, 20:45  ...      0.0          0.0
# 1      Saturday, 12 September 2020, 13:30  ...      0.0          1.0
# 2      Saturday, 12 September 2020, 13:30  ...      0.0          1.0
# 3      Saturday, 12 September 2020, 16:00  ...      0.0          0.0
# 4      Saturday, 12 September 2020, 16:00  ...      0.0          3.0
# ...                                   ...  ...      ...          ...
# 26819   Saturday, 27 February 2021, 14:00  ...      0.0          1.0
# 26820   Saturday, 27 February 2021, 14:00  ...      0.0          1.0
# 26821   Saturday, 27 February 2021, 14:00  ...      1.0          4.0
# 26822   Saturday, 27 February 2021, 16:00  ...      0.0          4.0
# 26823   Saturday, 27 February 2021, 18:00  ...      0.0          1.0
#
#        Away_Red  Categorical Result  home_EOL away_EOL  home_win  away_win  \
# 0           0.0            Home Win        65       60     57.8%     17.1%
# 1           0.0            Home Win        52       59     32.7%     43.6%
# 2           0.0            Away Win        41       48     29.9%     48.5%
# 3           0.0            Home Win        63       57     43.7%     32.7%
# 4           0.0            Away Win        47       50     47.1%     26.5%
# ...         ...                 ...       ...      ...       ...       ...
# 26819       0.0                Draw        55       48     31.8%     43.6%
# 26820       0.0                Draw        58       59     21.4%     52.9%
# 26821       0.0            Away Win        60       39     60.9%     18.3%
# 26822       0.0                Draw        51       58     38.5%     38.2%
# 26823       0.0                Draw        51       61     39.8%     30.9%
#
#         draw Error
# 0        25%   NaN
# 1      23.8%   NaN
# 2      21.6%   NaN
# 3      23.6%   NaN
# 4      26.4%   NaN
# ...      ...   ...
# 26819  24.6%   NaN
# 26820  25.7%   NaN
# 26821  20.8%   NaN
# 26822  23.3%   NaN
# 26823  29.3%   NaN
#
# [26824 rows x 22 columns]

# %%
champo2021 = df[df['League']=='championship']

# %%
champo2021
# Out:
#      Unnamed: 0          Home_Team          Away_Team Result  \
# 0             0            Watford      Middlesbrough    1-0
# 1             1    Birmingham City          Brentford    1-0
# 2             2  Wycombe Wanderers   Rotherham United    0-1
# 3             3    AFC Bournemouth   Blackburn Rovers    3-2
# 4             4           Barnsley         Luton Town    0-1
# ..          ...                ...                ...    ...
# 385         385      Middlesbrough       Cardiff City    1-1
# 386         386  Preston North End  Huddersfield Town    3-0
# 387         387   Rotherham United            Reading    0-1
# 388         388       Swansea City       Bristol City    1-3
# 389         389  Wycombe Wanderers       Norwich City    0-2
#
#                                                   Link  Season  Round  \
# 0    https://www.besoccer.com/match/watford-fc/midd...    2021      1
# 1    https://www.besoccer.com/match/birmingham-city...    2021      1
# 2    https://www.besoccer.com/match/wycombe-wandere...    2021      1
# 3    https://www.besoccer.com/match/afc-bournemouth...    2021      1
# 4    https://www.besoccer.com/match/barnsley-fc/lut...    2021      1
# ..                                                 ...     ...    ...
# 385  https://www.besoccer.com/match/middlesbrough-f...    2021     33
# 386  https://www.besoccer.com/match/preston-north-e...    2021     33
# 387  https://www.besoccer.com/match/rotherham-unite...    2021     33
# 388  https://www.besoccer.com/match/swansea-city-af...    2021     33
# 389  https://www.besoccer.com/match/wycombe-wandere...    2021     33
#
#            League                                       reduced_link  \
# 0    championship            /match/watford-fc/middlesbrough-fc/2021
# 1    championship           /match/birmingham-city-fc/brentford/2021
# 2    championship     /match/wycombe-wanderers/rotherham-united/2021
# 3    championship    /match/afc-bournemouth/blackburn-rovers-fc/2021
# 4    championship              /match/barnsley-fc/luton-town-fc/2021
# ..            ...                                                ...
# 385  championship       /match/middlesbrough-fc/cardiff-city-fc/2021
# 386  championship  /match/preston-north-end/huddersfield-town-fc/...
# 387  championship            /match/rotherham-united/reading-fc/2021
# 388  championship       /match/swansea-city-afc/bristol-city-fc/2021
# 389  championship      /match/wycombe-wanderers/norwich-city-fc/2021
#
#                                Date_New  ... Home_Red  Away_Yellow  Away_Red  \
# 0      Friday, 11 September 2020, 20:45  ...      0.0          0.0       0.0
# 1    Saturday, 12 September 2020, 13:30  ...      0.0          1.0       0.0
# 2    Saturday, 12 September 2020, 13:30  ...      0.0          1.0       0.0
# 3    Saturday, 12 September 2020, 16:00  ...      0.0          0.0       0.0
# 4    Saturday, 12 September 2020, 16:00  ...      0.0          3.0       0.0
# ..                                  ...  ...      ...          ...       ...
# 385   Saturday, 27 February 2021, 16:00  ...      0.0          3.0       0.0
# 386   Saturday, 27 February 2021, 16:00  ...      0.0          3.0       0.0
# 387   Saturday, 27 February 2021, 16:00  ...      0.0          0.0       0.0
# 388   Saturday, 27 February 2021, 16:00  ...      0.0          2.0       0.0
# 389     Sunday, 28 February 2021, 13:00  ...      0.0          1.0       0.0
#
#      Categorical Result  home_EOL away_EOL  home_win  away_win   draw Error
# 0              Home Win        65       60     57.8%     17.1%    25%   NaN
# 1              Home Win        52       59     32.7%     43.6%  23.8%   NaN
# 2              Away Win        41       48     29.9%     48.5%  21.6%   NaN
# 3              Home Win        63       57     43.7%     32.7%  23.6%   NaN
# 4              Away Win        47       50     47.1%     26.5%  26.4%   NaN
# ..                  ...       ...      ...       ...       ...    ...   ...
# 385                Draw        60       60     45.3%     27.9%  26.9%   NaN
# 386            Home Win        60       57     34.5%     29.2%  36.3%   NaN
# 387            Away Win        45       56     38.2%     37.1%  24.7%   NaN
# 388            Away Win        70       60     47.9%     25.9%  26.2%   NaN
# 389            Away Win        37       70     11.4%     70.9%  17.7%   NaN
#
# [390 rows x 22 columns]

# %%
def eval_result(result:str):
    result_list = result.split("-")
    try:
        return int(result_list[0])-int(result_list[1])
    except:
        return "Unknown"

# %%
champo2021['goal_diff'] = champo2021['Result'].apply(eval_result)
# Out:
# /var/folders/dn/_ysfbs6s2vz_pmnp3hg_bkgc0000gn/T/ipykernel_48983/3304734329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   champo2021['goal_diff'] = champo2021['Result'].apply(eval_result)

# %%
champo2021
# Out:
#      Unnamed: 0          Home_Team          Away_Team Result  \
# 0             0            Watford      Middlesbrough    1-0
# 1             1    Birmingham City          Brentford    1-0
# 2             2  Wycombe Wanderers   Rotherham United    0-1
# 3             3    AFC Bournemouth   Blackburn Rovers    3-2
# 4             4           Barnsley         Luton Town    0-1
# ..          ...                ...                ...    ...
# 385         385      Middlesbrough       Cardiff City    1-1
# 386         386  Preston North End  Huddersfield Town    3-0
# 387         387   Rotherham United            Reading    0-1
# 388         388       Swansea City       Bristol City    1-3
# 389         389  Wycombe Wanderers       Norwich City    0-2
#
#                                                   Link  Season  Round  \
# 0    https://www.besoccer.com/match/watford-fc/midd...    2021      1
# 1    https://www.besoccer.com/match/birmingham-city...    2021      1
# 2    https://www.besoccer.com/match/wycombe-wandere...    2021      1
# 3    https://www.besoccer.com/match/afc-bournemouth...    2021      1
# 4    https://www.besoccer.com/match/barnsley-fc/lut...    2021      1
# ..                                                 ...     ...    ...
# 385  https://www.besoccer.com/match/middlesbrough-f...    2021     33
# 386  https://www.besoccer.com/match/preston-north-e...    2021     33
# 387  https://www.besoccer.com/match/rotherham-unite...    2021     33
# 388  https://www.besoccer.com/match/swansea-city-af...    2021     33
# 389  https://www.besoccer.com/match/wycombe-wandere...    2021     33
#
#            League                                       reduced_link  \
# 0    championship            /match/watford-fc/middlesbrough-fc/2021
# 1    championship           /match/birmingham-city-fc/brentford/2021
# 2    championship     /match/wycombe-wanderers/rotherham-united/2021
# 3    championship    /match/afc-bournemouth/blackburn-rovers-fc/2021
# 4    championship              /match/barnsley-fc/luton-town-fc/2021
# ..            ...                                                ...
# 385  championship       /match/middlesbrough-fc/cardiff-city-fc/2021
# 386  championship  /match/preston-north-end/huddersfield-town-fc/...
# 387  championship            /match/rotherham-united/reading-fc/2021
# 388  championship       /match/swansea-city-afc/bristol-city-fc/2021
# 389  championship      /match/wycombe-wanderers/norwich-city-fc/2021
#
#                                Date_New  ... Away_Yellow  Away_Red  \
# 0      Friday, 11 September 2020, 20:45  ...         0.0       0.0
# 1    Saturday, 12 September 2020, 13:30  ...         1.0       0.0
# 2    Saturday, 12 September 2020, 13:30  ...         1.0       0.0
# 3    Saturday, 12 September 2020, 16:00  ...         0.0       0.0
# 4    Saturday, 12 September 2020, 16:00  ...         3.0       0.0
# ..                                  ...  ...         ...       ...
# 385   Saturday, 27 February 2021, 16:00  ...         3.0       0.0
# 386   Saturday, 27 February 2021, 16:00  ...         3.0       0.0
# 387   Saturday, 27 February 2021, 16:00  ...         0.0       0.0
# 388   Saturday, 27 February 2021, 16:00  ...         2.0       0.0
# 389     Sunday, 28 February 2021, 13:00  ...         1.0       0.0
#
#      Categorical Result  home_EOL  away_EOL home_win  away_win   draw Error  \
# 0              Home Win        65        60    57.8%     17.1%    25%   NaN
# 1              Home Win        52        59    32.7%     43.6%  23.8%   NaN
# 2              Away Win        41        48    29.9%     48.5%  21.6%   NaN
# 3              Home Win        63        57    43.7%     32.7%  23.6%   NaN
# 4              Away Win        47        50    47.1%     26.5%  26.4%   NaN
# ..                  ...       ...       ...      ...       ...    ...   ...
# 385                Draw        60        60    45.3%     27.9%  26.9%   NaN
# 386            Home Win        60        57    34.5%     29.2%  36.3%   NaN
# 387            Away Win        45        56    38.2%     37.1%  24.7%   NaN
# 388            Away Win        70        60    47.9%     25.9%  26.2%   NaN
# 389            Away Win        37        70    11.4%     70.9%  17.7%   NaN
#
#     goal_diff
# 0           1
# 1           1
# 2          -1
# 3           1
# 4          -1
# ..        ...
# 385         0
# 386         3
# 387        -1
# 388        -2
# 389        -2
#
# [390 rows x 23 columns]
